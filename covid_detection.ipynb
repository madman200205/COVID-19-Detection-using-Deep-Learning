# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Flatten
from keras. layers import MaxPooling2D
from keras.layers import Dense
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model=Sequential()
conv1=model.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(optimizer='adadelta',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.4,horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set =train_datagen.flow_from_directory('/content/drive/MyDrive/Deep Learning Contents/Deep Learning (26th April to 30th April, 2022)/Day 2/Afternoon/covid_data_updated/Train',target_size = (64, 64),batch_size = 8,class_mode = 'binary')
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Deep Learning Contents/Deep Learning (26th April to 30th April, 2022)/Day 2/Afternoon/covid_data_updated/test',target_size = (64, 64),batch_size = 8,class_mode = 'binary')
# Out:
# Found 238 images belonging to 2 classes.
# Found 39 images belonging to 2 classes.

# %%
type(training_set)
# Out:
# keras.preprocessing.image.DirectoryIterator

# %%
model.fit(training_set,steps_per_epoch = 20,epochs = 30)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 91s 4s/step - loss: 0.6835 - accuracy: 0.6013
# Epoch 2/30
# 20/20 [==============================] - 24s 1s/step - loss: 0.6563 - accuracy: 0.7025
# Epoch 3/30
# 20/20 [==============================] - 11s 576ms/step - loss: 0.6341 - accuracy: 0.7785
# Epoch 4/30
# 20/20 [==============================] - 5s 235ms/step - loss: 0.6053 - accuracy: 0.8250
# Epoch 5/30
# 20/20 [==============================] - 3s 143ms/step - loss: 0.5946 - accuracy: 0.8165
# Epoch 6/30
# 20/20 [==============================] - 4s 200ms/step - loss: 0.5603 - accuracy: 0.8101
# Epoch 7/30
# 20/20 [==============================] - 3s 124ms/step - loss: 0.5601 - accuracy: 0.7722
# Epoch 8/30
# 20/20 [==============================] - 2s 123ms/step - loss: 0.5730 - accuracy: 0.7975
# Epoch 9/30
# 20/20 [==============================] - 2s 119ms/step - loss: 0.5229 - accuracy: 0.8188
# Epoch 10/30
# 20/20 [==============================] - 3s 152ms/step - loss: 0.5364 - accuracy: 0.8101
# Epoch 11/30
# 20/20 [==============================] - 2s 116ms/step - loss: 0.5703 - accuracy: 0.7063
# Epoch 12/30
# 20/20 [==============================] - 3s 124ms/step - loss: 0.5122 - accuracy: 0.8313
# Epoch 13/30
# 20/20 [==============================] - 2s 120ms/step - loss: 0.5055 - accuracy: 0.8544
# Epoch 14/30
# 20/20 [==============================] - 3s 155ms/step - loss: 0.4890 - accuracy: 0.8481
# Epoch 15/30
# 20/20 [==============================] - 3s 123ms/step - loss: 0.5034 - accuracy: 0.8671
# Epoch 16/30
# 20/20 [==============================] - 2s 116ms/step - loss: 0.4889 - accuracy: 0.8544
# Epoch 17/30
# 20/20 [==============================] - 3s 122ms/step - loss: 0.4966 - accuracy: 0.8228
# Epoch 18/30
# 20/20 [==============================] - 3s 154ms/step - loss: 0.5002 - accuracy: 0.8101
# Epoch 19/30
# 20/20 [==============================] - 2s 120ms/step - loss: 0.4785 - accuracy: 0.8062
# Epoch 20/30
# 20/20 [==============================] - 2s 122ms/step - loss: 0.4514 - accuracy: 0.8671
# Epoch 21/30
# 20/20 [==============================] - 2s 121ms/step - loss: 0.4533 - accuracy: 0.8861
# Epoch 22/30
# 20/20 [==============================] - 3s 152ms/step - loss: 0.4939 - accuracy: 0.7658
# Epoch 23/30
# 20/20 [==============================] - 2s 118ms/step - loss: 0.4632 - accuracy: 0.8291
# Epoch 24/30
# 20/20 [==============================] - 2s 121ms/step - loss: 0.4700 - accuracy: 0.8101
# Epoch 25/30
# 20/20 [==============================] - 2s 119ms/step - loss: 0.4396 - accuracy: 0.8313
# Epoch 26/30
# 20/20 [==============================] - 3s 148ms/step - loss: 0.4125 - accuracy: 0.8861
# Epoch 27/30
# 20/20 [==============================] - 3s 126ms/step - loss: 0.4311 - accuracy: 0.8313
# Epoch 28/30
# 20/20 [==============================] - 3s 126ms/step - loss: 0.4618 - accuracy: 0.7911
# Epoch 29/30
# 20/20 [==============================] - 3s 158ms/step - loss: 0.4483 - accuracy: 0.7975
# Epoch 30/30
# 20/20 [==============================] - 2s 119ms/step - loss: 0.4375 - accuracy: 0.8608

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image
test_image =image.load_img('/content/drive/MyDrive/Deep Learning Contents/Deep Learning (26th April to 30th April, 2022)/Day 2/Afternoon/covid_data_updated/test/covid/Corona2_37.jpg',target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'Normal'
else:
  prediction = 'Corona'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Corona
